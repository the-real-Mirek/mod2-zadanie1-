# %%
import pandas as pd
import numpy as np
data = pd.read_html('https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/', header=0)
df = pd.DataFrame(data[0])

# %%
# Zamień nagłówki kolumn na polskie odpowiedniki: 
df.rename(columns={'TITLE':'TYTUŁ','ARTIST':'ARTYSTA', 'YEAR':'ROK', 'HIGH POSN':'MAX POZ'},inplace=True)
df
# Out:
#     POS                                   TYTUŁ                   ARTYSTA  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %%
# Ilu pojedynczych artystów znajduje się na liście?
pojedyńczy=df['ARTYSTA'].nunique()

# %%
# Które zespoły pojawiają się najczęściej na liście?
najczęściej=df['ARTYSTA'].value_counts().max()
najczęściej
i=0
max_artystów=df['ARTYSTA'].value_counts()
max_artystów2=max_artystów.reset_index()
test=max_artystów2.to_numpy()
lista_artystów=list()
for i in range(len(test)):
    if test[i][1]==najczęściej:
        lista_artystów.append(test[i][0])               
lista_artystów
# Out:
# ['COLDPLAY', 'TAKE THAT']

# %%
# Zmień nagłówki kolumn, tak aby każdy z nich rozpoczynał się od wielkiej litery, a pozostałe były wprowadzone małymi literami.
df.rename(str.capitalize, axis='columns',inplace=True)

# %%
# Wyrzuć z tabeli kolumnę ‘Max Poz’.
df.drop(['Max poz'],axis=1,inplace=True)
df
# Out:
#     Pos                                   Tytuł                   Artysta  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %%
# W którym roku wyszło najwięcej albumów znajdujących się na liście?
i=0
maks=df.groupby(['Rok']).count().max()[1]
rok_max_albumów=df.groupby(pd.Grouper(key='Rok')).agg({'Rok':'count'})
rok_max_albumów.rename(columns={'Rok':'ROK'},inplace=True)
rok_max_albumów2=rok_max_albumów.reset_index()
test=rok_max_albumów2.to_numpy()
lista_lat=list()
for i in range(len(test)):
    if test[i][1]==maks:
        lista_lat.append(test[i][0])
               
lista_lat
# Out:
# [1987, 2000]

# %%
# Ile albumów wydanych między 1960 a 1990 rokiem włącznie znajduje się na liście?
filtr_dat=df[(df['Rok']>=1960)&(df['Rok']<=1990)].count()[0]

# %%
# W którym roku wydany został najmłodszy album na liście?
najmłodszy = df['Rok'].max()

# %%
# Przygotuj listę najwcześniej wydanych albumów każdego artysty, który znalazł się na liście.
df2=df.sort_values(by='Rok',ascending=True)
df2.drop_duplicates(subset='Artysta',inplace=True)
artyści_lata=df2[['Artysta','Rok']].to_numpy()
artyści_lata
# Out:
# array([['ORIGINAL CAST RECORDING', 1965],
#        ['BEATLES', 1967],
#        ['SIMON & GARFUNKEL', 1970],
#        ['PINK FLOYD', 1973],
#        ['MIKE OLDFIELD', 1973],
#        ['ABBA', 1975],
#        ['MEAT LOAF', 1977],
#        ['FLEETWOOD MAC', 1977],
#        ['ORIGINAL SOUNDTRACK', 1977],
#        ['JEFF WAYNE', 1978],
#        ['QUEEN', 1981],
#        ['MICHAEL JACKSON', 1982],
#        ['BOB MARLEY & THE WAILERS', 1984],
#        ['DIRE STRAITS', 1985],
#        ['PAUL SIMON', 1986],
#        ['U2', 1987],
#        ['TRACY CHAPMAN', 1988],
#        ['PHIL COLLINS', 1989],
#        ['MADONNA', 1990],
#        ['SIMPLY RED', 1991],
#        ['REM', 1992],
#        ['OASIS', 1995],
#        ['ALANIS MORISSETTE', 1995],
#        ['SPICE GIRLS', 1996],
#        ['CORRS', 1997],
#        ['SHANIA TWAIN', 1997],
#        ['VERVE', 1997],
#        ['DAVID GRAY', 1998],
#        ['GEORGE MICHAEL', 1998],
#        ['ROBBIE WILLIAMS', 1998],
#        ['TRAVIS', 1999],
# ...

# %%
# Listę zapisz do pliku csv.
df.to_csv('C:\\Users\\MirekR\\Documents\\Python\\kodilla\\the-best-selling-albums-of-all-time-on-the-official-uk-chart.csv', index=False)

# %%
print('Ilu pojedynczych artystów znajduje się na liście? Odp:',pojedyńczy)
print('\n')
print('Które zespoły pojawiają się najczęściej na liście? Odp:',lista_artystów)
print('\n')
print('W którym roku wyszło najwięcej albumów znajdujących się na liście? Odp:',lista_lat)
print('\n')
print('Ile albumów wydanych między 1960 a 1990 rokiem włącznie znajduje się na liście? Odp:',filtr_dat)
print('\n')
print('W którym roku wydany został najmłodszy album na liście? Odp:',najmłodszy)
print('\n')
print('Przygotuj listę najwcześniej wydanych albumów każdego artysty, który znalazł się na liście.\n',artyści_lata)
# Out:
# Ilu pojedynczych artystów znajduje się na liście? Odp: 47
#
#
# Które zespoły pojawiają się najczęściej na liście? Odp: ['COLDPLAY', 'TAKE THAT']
#
#
# W którym roku wyszło najwięcej albumów znajdujących się na liście? Odp: [1987, 2000]
#
#
# Ile albumów wydanych między 1960 a 1990 rokiem włącznie znajduje się na liście? Odp: 22
#
#
# W którym roku wydany został najmłodszy album na liście? Odp: 2015
#
#
# Przygotuj listę najwcześniej wydanych albumów każdego artysty, który znalazł się na liście.
#  [['ORIGINAL CAST RECORDING' 1965]
#  ['BEATLES' 1967]
#  ['SIMON & GARFUNKEL' 1970]
#  ['PINK FLOYD' 1973]
#  ['MIKE OLDFIELD' 1973]
#  ['ABBA' 1975]
#  ['MEAT LOAF' 1977]
#  ['FLEETWOOD MAC' 1977]
#  ['ORIGINAL SOUNDTRACK' 1977]
#  ['JEFF WAYNE' 1978]
#  ['QUEEN' 1981]
#  ['MICHAEL JACKSON' 1982]
#  ['BOB MARLEY & THE WAILERS' 1984]
#  ['DIRE STRAITS' 1985]
#  ['PAUL SIMON' 1986]
#  ['U2' 1987]
#  ['TRACY CHAPMAN' 1988]
#  ['PHIL COLLINS' 1989]
#  ['MADONNA' 1990]
#  ['SIMPLY RED' 1991]
# ...
